# %% [markdown]
# # Exploratory Data Analysis (EDA).

# %%
mobiles=pd.read_csv('mobiles6.csv')

# %%
mobiles.head()
# Out:
#    Unnamed: 0    Brand        Product      MRP  Offer   Price           Color  \
# 0           0    REDMI            9i    9999.0   20.0  7999.0  Midnight Black
# 1           1  Infinix   Hot 10 Play   10999.0   22.0  8499.0       7° Purple
# 2           2  Infinix   Hot 10 Play   10999.0   22.0  8499.0     Aegean Blue
# 3           3  Infinix   Hot 10 Play   10999.0   22.0  8499.0   Morandi Green
# 4           4   realme     Narzo 30A   10999.0   13.0  9499.0      Laser Blue
#
#    Rating  Ratings1  Reeviews1  Display  Battery  RAM   ROM Warranty  \
# 0     4.3    289634      16396    16.59   5000.0  4.0  64.0   1 Year
# 1     4.3     10555        797    17.32   6000.0  4.0  64.0   1 Year
# 2     4.3     10555        797    17.32   6000.0  4.0  64.0   1 Year
# 3     4.3     10555        797    17.32   6000.0  4.0  64.0   1 Year
# 4     4.4     46113       2827    16.54   6000.0  4.0  64.0   1 Year
#
#                         Processor
# 0  ryMediaTek Helio G25 Processor
# ...

# %% [markdown]
# ### 1. Univariate Analysis.

# %%
plt.figure(figsize=(50,10))
sns.countplot(x=mobiles.Brand)
plt.show()

# %% [markdown]
# ### In Flipkart Samsung Brand mobiles are providing more products.
# ### Realme Brand tooks the next place.

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=mobiles.Rating)
plt.show()

# %% [markdown]
# ### Most of the mobiles having 4.3 rating.
# ### Only few mobiles having 5.0 (highest) rating.

# %%
(mobiles['Price'].value_counts().head(30)).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### In Flipkart most of the mobiles are having below 10999 price. That means most people choosing this price range.
# ### Most of the mobile brands are providing wide range of products in this Range.

# %%
mobiles['Price'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
mobiles[mobiles['Price']<15000]['Price'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ####  Categorical vs Numerical

# %%
plt.figure(figsize=(80,10))
sns.barplot(x=mobiles['Brand'],y=mobiles['Price'])
plt.show()

# %% [markdown]
# ### Apple mobile brands are having highest price

# %%
plt.figure(figsize=(80,10))
sns.barplot(x=mobiles['Brand'],y=mobiles['Rating'])
plt.show()

# %% [markdown]
# ### MI mobiles Brand having highest srar Rating.

# %%
plt.figure(figsize=(80,10))
sns.barplot(x=mobiles['Brand'],y=mobiles['Offer'])
plt.show()

# %% [markdown]
# ### KXD mobiles are giving more than 37% Offer on MRP.
# ### Even LG ,Gionee and micromax mobiles are giving more than 30% Offer on MRP.

# %%
plt.figure(figsize=(80,10))
sns.barplot(x=mobiles['Brand'],y=mobiles['Ratings1'])
plt.show()

# %% [markdown]
# ### In Flipkart Redmi mobile brand is the most selling brand, because most of the people gave ratings to this particular Brand
# ### Poco Brand is in second place.

# %%
plt.figure(figsize=(80,10))
sns.barplot(x=mobiles['Brand'],y=mobiles['RAM'])
plt.show()

# %% [markdown]
# ### In Flipkart ASUS and IQOO brand mobiles gives maximun GB RAM.

# %%
sns.kdeplot(mobiles.Price)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
Price50 = mobiles.nlargest(50, "Price")

# %%
Price50
# Out:
#      Unnamed: 0    Brand                             Product       MRP  Offer  \
# 848         927    APPLE                  iPhone 12 Pro Max   159900.0    2.0
# 868         951    APPLE                  iPhone 12 Pro Max   129900.0    3.0
# 864         947    APPLE                      iPhone 12 Pro   119900.0    3.0
# 824         888  SAMSUNG                   Galaxy S21 Ultra   128999.0   17.0
# 414         432    APPLE                          iPhone 12        NaN    NaN
# 464         485    APPLE                          iPhone 12    84900.0    2.0
# 535         559    APPLE                          iPhone 12    84900.0    2.0
# 601         632    APPLE                          iPhone 12    84900.0    2.0
# 629         661    APPLE                          iPhone 12    84900.0    2.0
# 793         854    APPLE                          iPhone 12    84900.0    2.0
# 765         819    APPLE                          iPhone 12        NaN    NaN
# ...

# %%
Price50.replace(np.NaN,0)
# Out:
#      Unnamed: 0    Brand                             Product       MRP  Offer  \
# 848         927    APPLE                  iPhone 12 Pro Max   159900.0    2.0
# 868         951    APPLE                  iPhone 12 Pro Max   129900.0    3.0
# 864         947    APPLE                      iPhone 12 Pro   119900.0    3.0
# 824         888  SAMSUNG                   Galaxy S21 Ultra   128999.0   17.0
# 414         432    APPLE                          iPhone 12        0.0    0.0
# 464         485    APPLE                          iPhone 12    84900.0    2.0
# 535         559    APPLE                          iPhone 12    84900.0    2.0
# 601         632    APPLE                          iPhone 12    84900.0    2.0
# 629         661    APPLE                          iPhone 12    84900.0    2.0
# 793         854    APPLE                          iPhone 12    84900.0    2.0
# 765         819    APPLE                          iPhone 12        0.0    0.0
# ...

# %%
Price50.isnull().sum()
# Out:
# Unnamed: 0     0
# Brand          0
# Product        0
# MRP            6
# Offer          6
# Price          0
# Color          0
# Rating         0
# Ratings1       0
# Reeviews1      0
# Display        1
# Battery       40
# RAM           40
# ROM            0
# Warranty       0
# Processor     40
# dtype: int64

# %%
Price50=Price50.dropna(how='any')

# %%
Price50.isnull().sum()
# Out:
# Unnamed: 0    0
# Brand         0
# Product       0
# MRP           0
# Offer         0
# Price         0
# Color         0
# Rating        0
# Ratings1      0
# Reeviews1     0
# Display       0
# Battery       0
# RAM           0
# ROM           0
# Warranty      0
# Processor     0
# dtype: int64

# %%
Price50.plot.line()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Brand',y='Display',data=Price50)
plt.show()

# %% [markdown]
# ### Samsung mobiles having larger display with lower cost compare top Apple Brand
# ### Asus brand tooks the next place(in Top 50 priced mobile brands).

# %%
plt.figure(figsize=(80,10))
sns.lineplot(x='Brand',y='RAM',data=mobiles)
plt.show()

# %% [markdown]
# ## Multi variste Analysis

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Brand',y='MRP' , data=mobiles.head(100),hue='Offer')
plt.show()

# %% [markdown]
# ### Only  Nokia brand gives the offer(12%) on lowest price mobiles.

# %%
sns.pairplot(Price50)
plt.show()

# %%
sns.pairplot(Price50,hue='Warranty')
plt.show()

# %% [markdown]
# ### Sorting  the Data for More Observations

# %%
mobiles.sort_values(by="Price",ascending=False)
# Out:
#      Unnamed: 0    Brand              Product       MRP  Offer     Price  \
# 848         927    APPLE   iPhone 12 Pro Max   159900.0    2.0  155900.0
# 868         951    APPLE   iPhone 12 Pro Max   129900.0    3.0  125900.0
# 864         947    APPLE       iPhone 12 Pro   119900.0    3.0  115900.0
# 824         888  SAMSUNG    Galaxy S21 Ultra   128999.0   17.0  105999.0
# 414         432    APPLE           iPhone 12        NaN    NaN   84900.0
# ..          ...      ...                  ...       ...    ...       ...
# 806         868        I                  NaN     749.0   13.0     649.0
# 637         669        I                  NaN     749.0   13.0     649.0
# 699         740    GFive                  NaN     679.0    5.0     645.0
# 698         739    GFive                  NaN     679.0    5.0     643.0
# 484         506   Salora                  NaN       NaN    NaN     639.0
#
#               Color  Rating  Ratings1  Reeviews1  Display  Battery   RAM  \
# ...

# %%
Mo=mobiles.replace(np.NaN,0)

# %%
Mo.sort_values(by="Price",ascending=False)
# Out:
#      Unnamed: 0    Brand              Product       MRP  Offer     Price  \
# 848         927    APPLE   iPhone 12 Pro Max   159900.0    2.0  155900.0
# 868         951    APPLE   iPhone 12 Pro Max   129900.0    3.0  125900.0
# 864         947    APPLE       iPhone 12 Pro   119900.0    3.0  115900.0
# 824         888  SAMSUNG    Galaxy S21 Ultra   128999.0   17.0  105999.0
# 414         432    APPLE           iPhone 12        0.0    0.0   84900.0
# ..          ...      ...                  ...       ...    ...       ...
# 806         868        I                    0     749.0   13.0     649.0
# 637         669        I                    0     749.0   13.0     649.0
# 699         740    GFive                    0     679.0    5.0     645.0
# 698         739    GFive                    0     679.0    5.0     643.0
# 484         506   Salora                    0       0.0    0.0     639.0
#
#               Color  Rating  Ratings1  Reeviews1  Display  Battery   RAM  \
# ...

# %%
m1=Mo[mobiles.Price>=15000]
m1
# Out:
#      Unnamed: 0   Brand              Product       MRP  Offer     Price  \
# 43           43  realme                8 5G    18999.0   10.0   16999.0
# 44           44  realme                8 5G    18999.0   10.0   16999.0
# 52           52  realme               8 Pro    21999.0    9.0   19999.0
# 59           59    OPPO             A53s 5G    18990.0   10.0   16990.0
# 65           65    POCO              X3 Pro    23999.0   20.0   18999.0
# ..          ...     ...                  ...       ...    ...       ...
# 864         947   APPLE       iPhone 12 Pro   119900.0    3.0  115900.0
# 865         948   APPLE      iPhone 12 Mini        0.0    0.0   69900.0
# 868         951   APPLE   iPhone 12 Pro Max   129900.0    3.0  125900.0
# 872         955   APPLE      iPhone 12 Mini        0.0    0.0   69900.0
# 873         956    ViVO                 Y50    19990.0   17.0   16490.0
#
#                    Color  Rating  Ratings1  Reeviews1  Display  Battery  RAM  \
# ...

# %%
m2=m1[m1.Price<=20000]

# %%
m2
# Out:
#      Unnamed: 0   Brand       Product      MRP  Offer    Price  \
# 43           43  realme         8 5G   18999.0   10.0  16999.0
# 44           44  realme         8 5G   18999.0   10.0  16999.0
# 52           52  realme        8 Pro   21999.0    9.0  19999.0
# 59           59    OPPO      A53s 5G   18990.0   10.0  16990.0
# 65           65    POCO       X3 Pro   23999.0   20.0  18999.0
# ..          ...     ...           ...      ...    ...      ...
# 840         908    ViVO        Z1Pro   20990.0   14.0  17990.0
# 842         913    ViVO        Z1Pro   20990.0   14.0  17990.0
# 853         934  realme        5 Pro       0.0    0.0  16999.0
# 855         937   Redmi   Note 7 Pro       0.0    0.0  16999.0
# 873         956    ViVO          Y50   19990.0   17.0  16490.0
#
#                    Color  Rating  Ratings1  Reeviews1  Display  Battery  RAM  \
# 43       Supersonic Blue     4.4      4602        465    16.51   5000.0  8.0
# ...

# %%
m2.replace(np.NaN,0)
# Out:
#      Unnamed: 0   Brand       Product      MRP  Offer    Price  \
# 43           43  realme         8 5G   18999.0   10.0  16999.0
# 44           44  realme         8 5G   18999.0   10.0  16999.0
# 52           52  realme        8 Pro   21999.0    9.0  19999.0
# 59           59    OPPO      A53s 5G   18990.0   10.0  16990.0
# 65           65    POCO       X3 Pro   23999.0   20.0  18999.0
# ..          ...     ...           ...      ...    ...      ...
# 840         908    ViVO        Z1Pro   20990.0   14.0  17990.0
# 842         913    ViVO        Z1Pro   20990.0   14.0  17990.0
# 853         934  realme        5 Pro       0.0    0.0  16999.0
# 855         937   Redmi   Note 7 Pro       0.0    0.0  16999.0
# 873         956    ViVO          Y50   19990.0   17.0  16490.0
#
#                    Color  Rating  Ratings1  Reeviews1  Display  Battery  RAM  \
# 43       Supersonic Blue     4.4      4602        465    16.51   5000.0  8.0
# ...

# %%
m3=m1[m1.Price>=20000]

# %%
m3
# Out:
#      Unnamed: 0    Brand              Product       MRP  Offer     Price  \
# 77           77     POCO              X3 Pro    25999.0   19.0   20999.0
# 117         117     POCO              X3 Pro    25999.0   19.0   20999.0
# 118         118    APPLE           iPhone 11    54900.0    8.0   49999.0
# 159         159  SAMSUNG          Galaxy F62    29999.0   20.0   23999.0
# 162         162  SAMSUNG          Galaxy F62    29999.0   20.0   23999.0
# ..          ...      ...                  ...       ...    ...       ...
# 863         946  SAMSUNG         Galaxy A70s        0.0    0.0   33100.0
# 864         947    APPLE       iPhone 12 Pro   119900.0    3.0  115900.0
# 865         948    APPLE      iPhone 12 Mini        0.0    0.0   69900.0
# 868         951    APPLE   iPhone 12 Pro Max   129900.0    3.0  125900.0
# 872         955    APPLE      iPhone 12 Mini        0.0    0.0   69900.0
#
#                Color  Rating  Ratings1  Reeviews1  Display  Battery  RAM  \
# ...

# %%
m4=m3[m3.Price<=50000]

# %%
m4
# Out:
#      Unnamed: 0    Brand                      Product      MRP  Offer  \
# 77           77     POCO                      X3 Pro   25999.0   19.0
# 117         117     POCO                      X3 Pro   25999.0   19.0
# 118         118    APPLE                   iPhone 11   54900.0    8.0
# 159         159  SAMSUNG                  Galaxy F62   29999.0   20.0
# 162         162  SAMSUNG                  Galaxy F62   29999.0   20.0
# ..          ...      ...                          ...      ...    ...
# 823         885       MI                      11X 5G       0.0    0.0
# 831         896    Apple   iPhone SE (White, 256 GB)   54900.0   14.0
# 844         922  SAMSUNG                  Galaxy M51       0.0    0.0
# 858         940   realme                  X50 Pro 5G   47999.0   35.0
# 863         946  SAMSUNG                 Galaxy A70s       0.0    0.0
#
#        Price                             Color  Rating  Ratings1  Reeviews1  \
# ...

# %%
 m5=m1[m1.Price>=50000]

# %%
m5
# Out:
#      Unnamed: 0    Brand              Product       MRP  Offer     Price  \
# 409         427    APPLE           iPhone 12    79900.0    2.0   77900.0
# 414         432    APPLE           iPhone 12        0.0    0.0   84900.0
# 464         485    APPLE           iPhone 12    84900.0    2.0   82900.0
# 517         540    APPLE       iPhone 11 Pro   106600.0   29.0   74999.0
# 535         559    APPLE           iPhone 12    84900.0    2.0   82900.0
# 586         617    APPLE           iPhone 12    79900.0    2.0   77900.0
# 601         632    APPLE           iPhone 12    84900.0    2.0   82900.0
# 607         638    APPLE           iPhone 12    79900.0    2.0   77900.0
# 621         653    APPLE      iPhone 12 Mini    69900.0    2.0   67900.0
# 629         661    APPLE           iPhone 12    84900.0    2.0   82900.0
# 763         817    APPLE           iPhone 12    79900.0    2.0   77900.0
# 765         819    APPLE           iPhone 12        0.0    0.0   79900.0
# ...

# %%
m6=m5[m5.Price<=100000]

# %%
m6
# Out:
#      Unnamed: 0  Brand           Product       MRP  Offer    Price  \
# 409         427  APPLE        iPhone 12    79900.0    2.0  77900.0
# 414         432  APPLE        iPhone 12        0.0    0.0  84900.0
# 464         485  APPLE        iPhone 12    84900.0    2.0  82900.0
# 517         540  APPLE    iPhone 11 Pro   106600.0   29.0  74999.0
# 535         559  APPLE        iPhone 12    84900.0    2.0  82900.0
# 586         617  APPLE        iPhone 12    79900.0    2.0  77900.0
# 601         632  APPLE        iPhone 12    84900.0    2.0  82900.0
# 607         638  APPLE        iPhone 12    79900.0    2.0  77900.0
# 621         653  APPLE   iPhone 12 Mini    69900.0    2.0  67900.0
# 629         661  APPLE        iPhone 12    84900.0    2.0  82900.0
# 763         817  APPLE        iPhone 12    79900.0    2.0  77900.0
# 765         819  APPLE        iPhone 12        0.0    0.0  79900.0
# 793         854  APPLE        iPhone 12    84900.0    2.0  82900.0
# ...

# %%
m7=m1[m1.Price>100000]

# %%
m7
# Out:
#      Unnamed: 0    Brand              Product       MRP  Offer     Price  \
# 824         888  SAMSUNG    Galaxy S21 Ultra   128999.0   17.0  105999.0
# 848         927    APPLE   iPhone 12 Pro Max   159900.0    2.0  155900.0
# 864         947    APPLE       iPhone 12 Pro   119900.0    3.0  115900.0
# 868         951    APPLE   iPhone 12 Pro Max   129900.0    3.0  125900.0
#
#               Color  Rating  Ratings1  Reeviews1  Display  Battery   RAM  \
# 824  Phantom Silver     4.5       447         92    17.27   5000.0  12.0
# 848    Pacific Blue     4.6       829         68    17.02      0.0   0.0
# 864    Pacific Blue     4.5       722         49    15.49      0.0   0.0
# 868        Graphite     4.6       828         68    17.02      0.0   0.0
#
#        ROM Warranty                Processor
# 824  256.0   1 Year  ryExynos 2100 Processor
# 848  512.0   1 Year                        0
# 864  128.0   1 Year                        0
# 868  128.0   1 Year                        0

# %%
m6.isnull().sum()
# Out:
# Unnamed: 0    0
# Brand         0
# Product       0
# MRP           0
# Offer         0
# Price         0
# Color         0
# Rating        0
# Ratings1      0
# Reeviews1     0
# Display       0
# Battery       0
# RAM           0
# ROM           0
# Warranty      0
# Processor     0
# dtype: int64

# %%
#Budget friendly mobiles price range 15000 to 20000

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=m2['Brand'],y=m2['MRP'])
plt.show()

# %% [markdown]
# ### Poco brand  gives you the wide range of mobiles in Budget.
# ### In Flipkart 9 mobile brands providing the different Products in Budget(15000 to 20000)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=m2['Brand'],y=m2['Rating'])
plt.show()

# %% [markdown]
# ### In budget friendly Brands Poco,Redmi,Vivo are the most rating brands.
# ### That means most of the people choose these brands with in Friendly Budget.

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='Brand',y='Price',data=m2)
plt.show()

# %% [markdown]
# ### Samsung Brand is having more products in Budget(15000 to 20000)

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='Brand',y='Offer',data=m2)
plt.show()

# %% [markdown]
# ### In budget friendly mobiles Samsung gives more discount.
# #### Samsung is the only Brand providing different products and also gives more Offer compare to other Brands.

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x='Brand',y='Reeviews1',data=m2)
plt.show()

# %% [markdown]
# ### Redmi mobiles are having more reviews in Budget friendly mobile Brands.
# ##### Redmi brand is the most selling brand in budget.(more people wrote the reviews).
# ###### After Redmi brand Realme brand tooks the next place.

# %%
#Medium budjet range between(20000 to 50000)

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=m4.Brand)
plt.show()

# %% [markdown]
# #### Samsung is providing more number of Products in medium budget.
# #### Moto,Asus,Google Poco Brands have less no of Products in Medium budget.

# %% [markdown]
# ### Bivariate Analysis (categorical vs Categorical)

# %%
plt.figure(figsize=(60,20))
sns.scatterplot(x='Brand',y='Product',data=m2)
plt.show()

# %% [markdown]
# ### Realme Brand has 11 different products  in Medium Budget.
# ##### Vivo brand is providing  7 different products  in Medium Budget.
# #### Infinix has only one Product in medium budget

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Brand',y='Offer',data=m4)
plt.show()

# %% [markdown]
# #### Poco  is giving morethan 17% offer compare to other brands in medium budjet .
# ##### Redmi Brand is giving less offer.

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x='Brand',y='Reeviews1',data=m4)
plt.show()

# %% [markdown]
# #### Apple brand mobiles having more reviews that means Apple is the most selling brand in Flipkart in medium budget.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Brand',y='Price',data=m6)
plt.show()

# %% [markdown]
# #### In Flipkart Apple is the only Brand available in Budget range between 50000 to 100000.
# ##### No other Brands provide any Provides any Products in this range.

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Brand',y='Product',data=m6)
plt.show()

# %% [markdown]
# #### Apple brand provides only three products in Budget range between 50000 to 100000

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Product',y='Ratings1',data=m6)
plt.show()

# %% [markdown]
# ####  In Apple brand iphone 11 pro has more ratings in Budget range between 50000 to 100000.
# #### So iphone 11 pro is the most selling product with in this budjet.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Brand',y='Price',data=m7)
plt.show()

# %% [markdown]
# #### In maximum budget (>100000) Flipkart provides only two Brands.
# ##### Apple and Samsung

# %% [markdown]
# ### Bivariate Analysis (categorical vs Categorical)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Brand',y='Product',data=m7)
plt.show()

# %% [markdown]
# #### Apple brand provides two products in maximum Budget.
# #### Those are iphone12 max, iphone 12 pro.
# #### Samsung provides only one product, and the product is Galaxy S21 Ultra.

# %%
Price10 = mobiles.nlargest(10,"MRP")

# %%
Price10
# Out:
#      Unnamed: 0    Brand              Product       MRP  Offer     Price  \
# 848         927    APPLE   iPhone 12 Pro Max   159900.0    2.0  155900.0
# 868         951    APPLE   iPhone 12 Pro Max   129900.0    3.0  125900.0
# 824         888  SAMSUNG    Galaxy S21 Ultra   128999.0   17.0  105999.0
# 864         947    APPLE       iPhone 12 Pro   119900.0    3.0  115900.0
# 517         540    APPLE       iPhone 11 Pro   106600.0   29.0   74999.0
# 464         485    APPLE           iPhone 12    84900.0    2.0   82900.0
# 535         559    APPLE           iPhone 12    84900.0    2.0   82900.0
# 601         632    APPLE           iPhone 12    84900.0    2.0   82900.0
# 629         661    APPLE           iPhone 12    84900.0    2.0   82900.0
# 793         854    APPLE           iPhone 12    84900.0    2.0   82900.0
#
#               Color  Rating  Ratings1  Reeviews1  Display  Battery   RAM  \
# 848    Pacific Blue     4.6       829         68    17.02      NaN   NaN
# ...

# %%
Price10['RAM']=Price10['RAM'].replace(np.NaN,10)

# %%
Price10['Battery']=Price10['Battery'].replace(np.NaN,6000)

# %%
Price10
# Out:
#      Unnamed: 0    Brand              Product       MRP  Offer     Price  \
# 848         927    APPLE   iPhone 12 Pro Max   159900.0    2.0  155900.0
# 868         951    APPLE   iPhone 12 Pro Max   129900.0    3.0  125900.0
# 824         888  SAMSUNG    Galaxy S21 Ultra   128999.0   17.0  105999.0
# 864         947    APPLE       iPhone 12 Pro   119900.0    3.0  115900.0
# 517         540    APPLE       iPhone 11 Pro   106600.0   29.0   74999.0
# 464         485    APPLE           iPhone 12    84900.0    2.0   82900.0
# 535         559    APPLE           iPhone 12    84900.0    2.0   82900.0
# 601         632    APPLE           iPhone 12    84900.0    2.0   82900.0
# 629         661    APPLE           iPhone 12    84900.0    2.0   82900.0
# 793         854    APPLE           iPhone 12    84900.0    2.0   82900.0
#
#               Color  Rating  Ratings1  Reeviews1  Display  Battery   RAM  \
# 848    Pacific Blue     4.6       829         68    17.02   6000.0  10.0
# ...

# %% [markdown]
# ### Pie chart

# %%
import matplotlib.pyplot as plt
Price10.Brand.value_counts(sort=False).plot.pie()
plt.show()

# %%
import matplotlib.pyplot as plt
Price10.Product.value_counts(sort=False).plot.pie()
plt.show()

# %% [markdown]
# ### Multivariate analysis(cat vs num)

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x='Brand',y='MRP', hue='Rating',data=Price10)
plt.show()

# %% [markdown]
# #### Apple brand Having more star ratings compare with Samsung.

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x='Brand',y='Battery', hue='Offer',data=Price10)
plt.show()

# %% [markdown]
# #### Samsung gives 17%offer on MRP having 5000mah battery.
# #### Apple brand gives less offer when compare with Samsung.

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Brand',y='Color', hue='Offer',data=Price10)
plt.show()

# %% [markdown]
# ### Apple Brand Provides 7 differentcolors in maximum budget(>100000)
# ### Apple brand gives more disount(29%) on Midnight Green color mobiles when compare with other colors.

# %%
mobiles.corr()
# Out:
#             Unnamed: 0       MRP     Offer     Price    Rating  Ratings1  \
# Unnamed: 0    1.000000  0.100754 -0.359044  0.022816 -0.386615 -0.172197
# MRP           0.100754  1.000000 -0.055869  0.991900  0.570716 -0.013014
# Offer        -0.359044 -0.055869  1.000000 -0.137835  0.046525  0.068028
# Price         0.022816  0.991900 -0.137835  1.000000  0.568607  0.025946
# Rating       -0.386615  0.570716  0.046525  0.568607  1.000000  0.261501
# Ratings1     -0.172197 -0.013014  0.068028  0.025946  0.261501  1.000000
# Reeviews1    -0.173164  0.001512  0.093554  0.034169  0.265383  0.984533
# Display      -0.311740 -0.259205  0.100452 -0.285800  0.000950  0.007985
# Battery      -0.451187  0.531422  0.235359  0.634872  0.628687  0.220269
# RAM           0.041419  0.800089 -0.075986  0.794752  0.321033 -0.085025
# ROM           0.099911  0.530900 -0.100755  0.483957  0.301263 -0.098850
#
#             Reeviews1   Display   Battery       RAM       ROM
# ...

# %% [markdown]
# ## Heat map

# %%
plt.figure(figsize=(15,10))
sns.heatmap(mobiles.corr(),annot=True)
plt.show()

# %% [markdown]
# ## Conclusion
# #### In Flipkart Samsung Brand mobiles are providing more products.Realme Brand tooks the next place.
# #### In Flipkart most of the mobiles having price below 10999.
# #### Most of the mobile brands are providing wide range of products in this Range that means most of the people choosing this price range.
# #### KXD mobiles are giving more than 37% Offer on MRP.
# #### Even LG ,Gionee and micromax mobiles are giving more than 30% Offer on MRP.
# #### In Flipkart Redmi mobile brand is the most selling brand, because most of the people gave ratings to this particular Brand
# #### Poco brand is in second place.
# #### In Flipkart ASUS and IQOO brand mobiles gives maximum GB RAM.
# #### Redmi mobiles are having more reviews in Budget friendly mobile Brands(15000 to 20000).
# #### Redmi brand is the most selling brand in budget.(more people wrote the reviews).
# #### Poco brand  gives you the wide range of mobiles in Budget.
# #### In Flipkart  9mobilebrands (realme,oppo,poco,Motorola,REDMI,Samsung,vivo,infinix,Redmi) providing the different Products in Budget(15000 to 20000)
# #### In maximum budget (>100000) Flipkart provides only two Brands.
# #### Apple and Samsung
